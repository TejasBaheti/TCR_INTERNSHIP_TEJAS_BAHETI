# %% [raw]
# Name : Tejas Baheti
# Batch : DATA SCIENCE WITH MACHINE LEARNING AND PYTHON
# PROJECT : ANTI PISHING PREDICTION

# %% [markdown]
#     Phishing is a kind of cybercrime where attacker pose as known or trusted entities and contact individuals through email, text or telephone and ask them to share sensitive information.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Importing The Data

data = pd.read_csv("Phishing_Legitimate_full.csv")

# %% [markdown]
# converting the data
#
#     Here we will convert the float64 and int64 values to type 32, to save memory usage.

# %%
data.shape
# Out:
# (10000, 50)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int64
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float64
#  28  PctExtResourceUrls                  10000 non-null  float64
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float64
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float64(3), int64(47)
# memory usage: 3.8 MB

# %%
float_col = data.select_dtypes('float64').columns
for x in float_col:
    data[x]=data[x].astype('float32')

# %%
int_col = data.select_dtypes('int64').columns
for x in int_col:
    data[x]=data[x].astype('int32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  49  CLASS_LABEL                         10000 non-null  int32
# dtypes: float32(3), int32(47)
# memory usage: 1.9 MB

# %%
data.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# 2              0             0                 0                 1
# 3              0             0                 0                 1
# 4              1             0                 0                 1
#
#    UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 0            0                     1                       1
# 1           -1                     1                       1
# 2            0                    -1                       1
# 3           -1                     1                       1
# 4            1                    -1                       0
#
#    ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  CLASS_LABEL
# 0                   -1                                   1            1
# 1                    1                                   1            1
# 2                   -1                                   0            1
# 3                    1                                  -1            1
# 4                   -1                                  -1            1
#
# [5 rows x 50 columns]

# %% [markdown]
# Summary Statistics:
#
#     By using the describe method, we can see some of the columns have high variance , this is due to the fact that some of the column have bigger values and bigger ranges

# %%
data.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      0.000000      0.000000
# 50%        0.000000           0.000000      0.000000      0.000000
# 75%        2.000000           0.000000      0.000000      0.000000
# max       55.000000           9.000000      1.000000      1.000000
#
#        NumUnderscore  ...  IframeOrFrame  MissingTitle  ImagesOnlyInForm  \
# count    10000.00000  ...   10000.000000   10000.00000      10000.000000
# mean         0.32320  ...       0.339600       0.03220          0.030400
# std          1.11466  ...       0.473597       0.17654          0.171694
# min          0.00000  ...       0.000000       0.00000          0.000000
# 25%          0.00000  ...       0.000000       0.00000          0.000000
# 50%          0.00000  ...       0.000000       0.00000          0.000000
# 75%          0.00000  ...       1.000000       0.00000          0.000000
# max         18.00000  ...       1.000000       1.00000          1.000000
#
#        SubdomainLevelRT   UrlLengthRT  PctExtResourceUrlsRT  \
# count      10000.000000  10000.000000          10000.000000
# mean           0.956600      0.020200              0.353300
# std            0.248037      0.820036              0.888908
# min           -1.000000     -1.000000             -1.000000
# 25%            1.000000     -1.000000             -1.000000
# 50%            1.000000      0.000000              1.000000
# 75%            1.000000      1.000000              1.000000
# max            1.000000      1.000000              1.000000
#
#        AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# count            10000.000000         10000.000000
# mean                 0.793200             0.173400
# std                  0.521019             0.755771
# min                 -1.000000            -1.000000
# 25%                  1.000000             0.000000
# 50%                  1.000000             0.000000
# 75%                  1.000000             1.000000
# max                  1.000000             1.000000
#
#        PctExtNullSelfRedirectHyperlinksRT   CLASS_LABEL
# count                        10000.000000  10000.000000
# mean                             0.314100      0.500000
# std                              0.897843      0.500025
# min                             -1.000000      0.000000
# 25%                             -1.000000      0.000000
# 50%                              1.000000      0.500000
# 75%                              1.000000      1.000000
# max                              1.000000      1.000000
#
# [8 rows x 50 columns]

# %% [markdown]
# Renaming column name for convenience

# %%
data.rename(columns={'CLASS_LABEL':'Label'},inplace=True)

# %%
data.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# 2              0             0                 0                 1
# 3              0             0                 0                 1
# 4              1             0                 0                 1
#
#    UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 0            0                     1                       1
# 1           -1                     1                       1
# 2            0                    -1                       1
# 3           -1                     1                       1
# 4            1                    -1                       0
#
#    ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  Label
# 0                   -1                                   1      1
# 1                    1                                   1      1
# 2                   -1                                   0      1
# 3                    1                                  -1      1
# 4                   -1                                  -1      1
#
# [5 rows x 50 columns]

# %%
data['Label'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Label'>

# %% [markdown]
# Data is Balanced for Pishing and Non Pishing Label

# %% [markdown]
# .

# %% [markdown]
# Mutual info
#
#     We will now use mutual information classifier to find non-linear and linear correlation between the features and "Label"

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
x=data.drop(['id','Label'],axis=1)

# %%
y=data['Label']

# %%
discrete_features = x.dtypes ==int

# %%
mi_scores = mutual_info_classif(x, y, discrete_features=discrete_features)
mi_scores = pd.Series(mi_scores, name='MI Scores', index=x.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
# Out:
# PctExtHyperlinks                      4.673976e-01
# PctExtResourceUrls                    2.910239e-01
# PctNullSelfRedirectHyperlinks         2.363445e-01
# PctExtNullSelfRedirectHyperlinksRT    2.123850e-01
# NumNumericChars                       1.326711e-01
# FrequentDomainNameMismatch            1.254908e-01
# ExtMetaScriptLinkRT                   1.175434e-01
# NumDash                               1.140136e-01
# SubmitInfoToEmail                     7.802617e-02
# NumDots                               6.553700e-02
# PathLength                            6.413269e-02
# QueryLength                           5.818557e-02
# PathLevel                             5.543887e-02
# InsecureForms                         5.508096e-02
# UrlLength                             5.263855e-02
# NumSensitiveWords                     4.180522e-02
# NumQueryComponents                    3.361768e-02
# PctExtResourceUrlsRT                  2.831059e-02
# IframeOrFrame                         2.805496e-02
# HostnameLength                        2.564249e-02
# NumAmpersand                          1.962894e-02
# AbnormalExtFormActionR                1.816610e-02
# UrlLengthRT                           1.513853e-02
# NumDashInHostname                     1.502933e-02
# IpAddress                             1.207265e-02
# AbnormalFormAction                    1.118934e-02
# EmbeddedBrandName                     1.066208e-02
# NumUnderscore                         1.037366e-02
# MissingTitle                          7.353661e-03
# DomainInPaths                         7.003483e-03
# SubdomainLevel                        6.392610e-03
# ExtFormAction                         5.613946e-03
# DomainInSubdomains                    5.497419e-03
# TildeSymbol                           5.362924e-03
# SubdomainLevelRT                      4.503644e-03
# NumPercent                            3.790407e-03
# RandomString                          3.643235e-03
# RelativeFormAction                    3.419686e-03
# RightClickDisabled                    3.024050e-03
# PopUpWindow                           2.919366e-03
# NoHttps                               2.854909e-03
# ExtFavicon                            2.398229e-03
# NumHash                               1.596890e-03
# DoubleSlashInPath                     3.101288e-04
# AtSymbol                              2.079892e-04
# FakeLinkInStatusBar                   1.113537e-04
# ImagesOnlyInForm                      6.785265e-07
# HttpsInHostname                       1.776357e-15
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width,scores)
    plt.yticks(width,ticks)
    plt.title("Mi Scores")

# %%
plt.figure(dpi=100, figsize=(12,12))
plot_mi_scores(mi_scores)

# %% [markdown]
# Prediction

# %% [markdown]
#     We will first use logistic regression as for baseline, then try to beat the baseline using random forest classifer
#
#     Our evaluation metrics will be accuracy, precision, recall and f1 score
#
#     Below we import all the required modules

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier as Rfc 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Train logistic models
#
#     This method is used to perform a repetative training process using logistic regression model, the main purpose for this is to find the optimal number of features that can be used to find the best fitted model without adjusting much of the hyperparameters, hence the idea here is to go with Data-Centric training, basically the method takes number of top N features to be used for training the model and all the evaluation metrics are returned for evaluation purpose

# %%
def train_logistic(data, top_n):
    top_n_features= mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    x=data[top_n_features]
    y= data['Label']
    
    x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, shuffle=True)
    
    LR = LogisticRegression(max_iter=10000)
    LR.fit(x_train, y_train)
    
    y_pred= LR.predict(x_test)
    
    precision=precision_score(y_test, y_pred) 
    recall=recall_score(y_test, y_pred)
    f1=f1_score(y_test, y_pred) 
    accuracy=accuracy_score(y_test, y_pred)
    
    return precision, recall,f1,accuracy

# %% [markdown]
#     Here the loop will be starting from 15 as we will start training with top 20 features up to all 50 features to find optimal number of features needed for this problem

# %%
arr=[]
for i in range(15,51,1):
    precision,recall,f1,accuracy=train_logistic(data,i)
    print("performance for logistic Model with Top {} features is precision :{}, recall :{}, f1 score :{}, accuracy :{}".format(i,precision,recall,f1,accuracy))
    arr.append([i,precision,recall,f1,accuracy])
# Out:
# performance for logistic Model with Top 15 features is precision :0.9179179179179179, recall :0.9309644670050762, f1 score :0.9243951612903226, accuracy :0.925
# performance for logistic Model with Top 16 features is precision :0.9072063178677197, recall :0.930161943319838, f1 score :0.9185407296351824, accuracy :0.9185
# performance for logistic Model with Top 17 features is precision :0.9173151750972762, recall :0.9254170755642787, f1 score :0.9213483146067416, accuracy :0.9195
# performance for logistic Model with Top 18 features is precision :0.9111747851002865, recall :0.9408284023668639, f1 score :0.9257641921397379, accuracy :0.9235
# performance for logistic Model with Top 19 features is precision :0.9120553359683794, recall :0.9418367346938775, f1 score :0.9267068273092368, accuracy :0.927
# performance for logistic Model with Top 20 features is precision :0.9270216962524654, recall :0.9362549800796812, f1 score :0.931615460852329, accuracy :0.931
# performance for logistic Model with Top 21 features is precision :0.9217221135029354, recall :0.9354518371400199, f1 score :0.9285362247412517, accuracy :0.9275
# performance for logistic Model with Top 22 features is precision :0.9283611383709519, recall :0.9403578528827038, f1 score :0.934320987654321, accuracy :0.9335
# performance for logistic Model with Top 23 features is precision :0.913913913913914, recall :0.9373716632443532, f1 score :0.9254941713127217, accuracy :0.9265
# performance for logistic Model with Top 24 features is precision :0.9177277179236043, recall :0.9474216380182002, f1 score :0.9323383084577114, accuracy :0.932
# performance for logistic Model with Top 25 features is precision :0.918407960199005, recall :0.9351570415400202, f1 score :0.9267068273092369, accuracy :0.927
# performance for logistic Model with Top 26 features is precision :0.9124378109452737, recall :0.9443872296601442, f1 score :0.9281376518218624, accuracy :0.929
# performance for logistic Model with Top 27 features is precision :0.9051808406647116, recall :0.937246963562753, f1 score :0.920934858279463, accuracy :0.9205
# performance for logistic Model with Top 28 features is precision :0.9251968503937008, recall :0.9297725024727992, f1 score :0.927479033053774, accuracy :0.9265
# performance for logistic Model with Top 29 features is precision :0.9305555555555556, recall :0.938938938938939, f1 score :0.9347284504235177, accuracy :0.9345
# performance for logistic Model with Top 30 features is precision :0.9352589641434262, recall :0.9306243805748265, f1 score :0.9329359165424739, accuracy :0.9325
# performance for logistic Model with Top 31 features is precision :0.9393638170974155, recall :0.9337944664031621, f1 score :0.9365708622398414, accuracy :0.936
# performance for logistic Model with Top 32 features is precision :0.9344587884806356, recall :0.9372509960159362, f1 score :0.9358528095474887, accuracy :0.9355
# performance for logistic Model with Top 33 features is precision :0.9305283757338552, recall :0.9425173439048563, f1 score :0.9364844903988183, accuracy :0.9355
# performance for logistic Model with Top 34 features is precision :0.931439764936337, recall :0.9406528189910979, f1 score :0.9360236220472441, accuracy :0.935
# performance for logistic Model with Top 35 features is precision :0.9358341559723593, recall :0.9275929549902152, f1 score :0.9316953316953317, accuracy :0.9305
# performance for logistic Model with Top 36 features is precision :0.9187620889748549, recall :0.949050949050949, f1 score :0.9336609336609337, accuracy :0.9325
# performance for logistic Model with Top 37 features is precision :0.937560975609756, recall :0.933009708737864, f1 score :0.935279805352798, accuracy :0.9335
# performance for logistic Model with Top 38 features is precision :0.9281437125748503, recall :0.9327983951855566, f1 score :0.9304652326163081, accuracy :0.9305
# performance for logistic Model with Top 39 features is precision :0.9357429718875502, recall :0.9404641775983855, f1 score :0.9380976346250629, accuracy :0.9385
# performance for logistic Model with Top 40 features is precision :0.9441117764471058, recall :0.9274509803921569, f1 score :0.9357072205736894, accuracy :0.935
# performance for logistic Model with Top 41 features is precision :0.9314009661835749, recall :0.9572989076464746, f1 score :0.9441723800195886, accuracy :0.943
# performance for logistic Model with Top 42 features is precision :0.9254032258064516, recall :0.9503105590062112, f1 score :0.9376915219611849, accuracy :0.939
# performance for logistic Model with Top 43 features is precision :0.935077519379845, recall :0.9516765285996055, f1 score :0.9433040078201368, accuracy :0.942
# performance for logistic Model with Top 44 features is precision :0.9358490566037736, recall :0.9501915708812261, f1 score :0.9429657794676807, accuracy :0.94
# performance for logistic Model with Top 45 features is precision :0.9429133858267716, recall :0.9419862340216323, f1 score :0.9424495818986719, accuracy :0.9415
# performance for logistic Model with Top 46 features is precision :0.9312681510164569, recall :0.9581673306772909, f1 score :0.944526264113893, accuracy :0.9435
# performance for logistic Model with Top 47 features is precision :0.9411764705882353, recall :0.9542743538767395, f1 score :0.9476801579466929, accuracy :0.947
# performance for logistic Model with Top 48 features is precision :0.9297029702970298, recall :0.9620901639344263, f1 score :0.945619335347432, accuracy :0.946
# performance for logistic Model with Top 49 features is precision :0.9322709163346613, recall :0.949290060851927, f1 score :0.9407035175879396, accuracy :0.941
# performance for logistic Model with Top 50 features is precision :0.9415204678362573, recall :0.9489194499017681, f1 score :0.9452054794520548, accuracy :0.944

# %%
df = pd.DataFrame(arr,columns=['num_of_features','precision','recall','f1_score','accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                15   0.917918  0.930964  0.924395    0.9250
# 1                16   0.907206  0.930162  0.918541    0.9185
# 2                17   0.917315  0.925417  0.921348    0.9195
# 3                18   0.911175  0.940828  0.925764    0.9235
# 4                19   0.912055  0.941837  0.926707    0.9270
# 5                20   0.927022  0.936255  0.931615    0.9310
# 6                21   0.921722  0.935452  0.928536    0.9275
# 7                22   0.928361  0.940358  0.934321    0.9335
# 8                23   0.913914  0.937372  0.925494    0.9265
# 9                24   0.917728  0.947422  0.932338    0.9320
# 10               25   0.918408  0.935157  0.926707    0.9270
# 11               26   0.912438  0.944387  0.928138    0.9290
# 12               27   0.905181  0.937247  0.920935    0.9205
# 13               28   0.925197  0.929773  0.927479    0.9265
# 14               29   0.930556  0.938939  0.934728    0.9345
# 15               30   0.935259  0.930624  0.932936    0.9325
# 16               31   0.939364  0.933794  0.936571    0.9360
# 17               32   0.934459  0.937251  0.935853    0.9355
# 18               33   0.930528  0.942517  0.936484    0.9355
# 19               34   0.931440  0.940653  0.936024    0.9350
# 20               35   0.935834  0.927593  0.931695    0.9305
# 21               36   0.918762  0.949051  0.933661    0.9325
# 22               37   0.937561  0.933010  0.935280    0.9335
# 23               38   0.928144  0.932798  0.930465    0.9305
# 24               39   0.935743  0.940464  0.938098    0.9385
# 25               40   0.944112  0.927451  0.935707    0.9350
# 26               41   0.931401  0.957299  0.944172    0.9430
# 27               42   0.925403  0.950311  0.937692    0.9390
# 28               43   0.935078  0.951677  0.943304    0.9420
# 29               44   0.935849  0.950192  0.942966    0.9400
# 30               45   0.942913  0.941986  0.942450    0.9415
# 31               46   0.931268  0.958167  0.944526    0.9435
# 32               47   0.941176  0.954274  0.947680    0.9470
# 33               48   0.929703  0.962090  0.945619    0.9460
# 34               49   0.932271  0.949290  0.940704    0.9410
# 35               50   0.941520  0.948919  0.945205    0.9440

# %% [markdown]
# Visualize Logistic Reg Performance
#
#     As we can see, the model had ups and downs during the training as more number of features were added, as our target is to maximize all the metrics we have to find the number of features that gives us the best of all metrics, from the figure below, we can see that recall is constantly performing good but our model tend to have problem with precision score, hence to choose the best N of features, we have to pick the area where all the metrics are performing and based on the figure I would say its around 39 features

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score') 
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score') 
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %% [markdown]
# Training Random Forest Classifier
#
#     Now we will use Random Forest Classification for training and try to beat the baseline set by logistic Regression

# %%
def train_rfc(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X=data[top_n_features]
    у=data['Label']

    x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, shuffle=True)

    rfc= Rfc(n_estimators=500,
             max_depth=32, 
             max_features=1.0, 
            )

    rfc.fit(x_train, y_train)

    y_pred = rfc.predict(x_test)

    precision = precision_score(y_test, y_pred) 
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred) 
    accuracy = accuracy_score(y_test, y_pred)

    return precision, recall,f1,accuracy

# %%
arr=[]
for i in range(15,51,1):
    precision,recall,f1,accuracy=train_rfc(data,i)
    print("performance for logistic Model with Top {} features is precision :{}, recall :{}, f1 score :{}, accuracy :{}".format(i,precision,recall,f1,accuracy))
    arr.append([i,precision,recall,f1,accuracy])
# Out:
# performance for logistic Model with Top 15 features is precision :0.9789272030651341, recall :0.9826923076923076, f1 score :0.9808061420345489, accuracy :0.98
# performance for logistic Model with Top 16 features is precision :0.9825462012320328, recall :0.9725609756097561, f1 score :0.9775280898876405, accuracy :0.978
# performance for logistic Model with Top 17 features is precision :0.9797160243407708, recall :0.9747729566094854, f1 score :0.9772382397572079, accuracy :0.9775
# performance for logistic Model with Top 18 features is precision :0.9799196787148594, recall :0.9779559118236473, f1 score :0.9789368104312939, accuracy :0.979
# performance for logistic Model with Top 19 features is precision :0.9643564356435643, recall :0.9878296146044625, f1 score :0.9759519038076153, accuracy :0.976
# performance for logistic Model with Top 20 features is precision :0.9739217652958877, recall :0.9827935222672065, f1 score :0.9783375314861461, accuracy :0.9785
# performance for logistic Model with Top 21 features is precision :0.9655172413793104, recall :0.9869083585095669, f1 score :0.9760956175298805, accuracy :0.976
# performance for logistic Model with Top 22 features is precision :0.9737354085603113, recall :0.985236220472441, f1 score :0.9794520547945206, accuracy :0.979
# performance for logistic Model with Top 23 features is precision :0.9708542713567839, recall :0.9837067209775967, f1 score :0.9772382397572078, accuracy :0.9775
# performance for logistic Model with Top 24 features is precision :0.9827586206896551, recall :0.9799426934097422, f1 score :0.981348637015782, accuracy :0.9805
# performance for logistic Model with Top 25 features is precision :0.9754178957718781, recall :0.9678048780487805, f1 score :0.9715964740450538, accuracy :0.971
# performance for logistic Model with Top 26 features is precision :0.9865841073271414, recall :0.9815195071868583, f1 score :0.984045290787442, accuracy :0.9845
# performance for logistic Model with Top 27 features is precision :0.9811320754716981, recall :0.9801587301587301, f1 score :0.9806451612903226, accuracy :0.9805
# performance for logistic Model with Top 28 features is precision :0.9796541200406917, recall :0.9836567926455567, f1 score :0.981651376146789, accuracy :0.982
# performance for logistic Model with Top 29 features is precision :0.9824902723735408, recall :0.9805825242718447, f1 score :0.9815354713313896, accuracy :0.981
# performance for logistic Model with Top 30 features is precision :0.9771825396825397, recall :0.9820538384845464, f1 score :0.9796121332670313, accuracy :0.9795
# performance for logistic Model with Top 31 features is precision :0.974025974025974, recall :0.9779338014042126, f1 score :0.975975975975976, accuracy :0.976
# performance for logistic Model with Top 32 features is precision :0.973293768545994, recall :0.9791044776119403, f1 score :0.9761904761904762, accuracy :0.976
# performance for logistic Model with Top 33 features is precision :0.9763079960513327, recall :0.9821251241310824, f1 score :0.9792079207920793, accuracy :0.979
# performance for logistic Model with Top 34 features is precision :0.9755102040816327, recall :0.9805128205128205, f1 score :0.9780051150895142, accuracy :0.9785
# performance for logistic Model with Top 35 features is precision :0.9770992366412213, recall :0.982725527831094, f1 score :0.9799043062200956, accuracy :0.979
# performance for logistic Model with Top 36 features is precision :0.9813542688910697, recall :0.9784735812133072, f1 score :0.9799118079372856, accuracy :0.9795
# performance for logistic Model with Top 37 features is precision :0.9856850715746421, recall :0.9806714140386572, f1 score :0.9831718510963794, accuracy :0.9835
# performance for logistic Model with Top 38 features is precision :0.9753593429158111, recall :0.9753593429158111, f1 score :0.9753593429158111, accuracy :0.976
# performance for logistic Model with Top 39 features is precision :0.9676113360323887, recall :0.9775051124744376, f1 score :0.9725330620549338, accuracy :0.973
# performance for logistic Model with Top 40 features is precision :0.9807692307692307, recall :0.9748490945674044, f1 score :0.9778002018163471, accuracy :0.978
# performance for logistic Model with Top 41 features is precision :0.9765545361875637, recall :0.9755600814663951, f1 score :0.9760570555272541, accuracy :0.9765
# performance for logistic Model with Top 42 features is precision :0.9724770642201835, recall :0.9764585465711362, f1 score :0.9744637385086823, accuracy :0.975
# performance for logistic Model with Top 43 features is precision :0.9775739041794088, recall :0.9726166328600405, f1 score :0.9750889679715302, accuracy :0.9755
# performance for logistic Model with Top 44 features is precision :0.9810568295114656, recall :0.9704142011834319, f1 score :0.9757064947942488, accuracy :0.9755
# performance for logistic Model with Top 45 features is precision :0.9802371541501976, recall :0.9860834990059643, f1 score :0.983151635282458, accuracy :0.983
# performance for logistic Model with Top 46 features is precision :0.9707887049659202, recall :0.9812992125984252, f1 score :0.9760156632403328, accuracy :0.9755
# performance for logistic Model with Top 47 features is precision :0.9705593719332679, recall :0.98998998998999, f1 score :0.9801783944499505, accuracy :0.98
# performance for logistic Model with Top 48 features is precision :0.9756572541382668, recall :0.978515625, f1 score :0.9770843490980009, accuracy :0.9765
# performance for logistic Model with Top 49 features is precision :0.9742319127849356, recall :0.9810379241516967, f1 score :0.9776230730979611, accuracy :0.9775
# performance for logistic Model with Top 50 features is precision :0.9809428284854563, recall :0.9799599198396793, f1 score :0.9804511278195489, accuracy :0.9805

# %%
df = pd.DataFrame(arr,columns=['num_of_features','precision','recall','f1_score','accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                15   0.978927  0.982692  0.980806    0.9800
# 1                16   0.982546  0.972561  0.977528    0.9780
# 2                17   0.979716  0.974773  0.977238    0.9775
# 3                18   0.979920  0.977956  0.978937    0.9790
# 4                19   0.964356  0.987830  0.975952    0.9760
# 5                20   0.973922  0.982794  0.978338    0.9785
# 6                21   0.965517  0.986908  0.976096    0.9760
# 7                22   0.973735  0.985236  0.979452    0.9790
# 8                23   0.970854  0.983707  0.977238    0.9775
# 9                24   0.982759  0.979943  0.981349    0.9805
# 10               25   0.975418  0.967805  0.971596    0.9710
# 11               26   0.986584  0.981520  0.984045    0.9845
# 12               27   0.981132  0.980159  0.980645    0.9805
# 13               28   0.979654  0.983657  0.981651    0.9820
# 14               29   0.982490  0.980583  0.981535    0.9810
# 15               30   0.977183  0.982054  0.979612    0.9795
# 16               31   0.974026  0.977934  0.975976    0.9760
# 17               32   0.973294  0.979104  0.976190    0.9760
# 18               33   0.976308  0.982125  0.979208    0.9790
# 19               34   0.975510  0.980513  0.978005    0.9785
# 20               35   0.977099  0.982726  0.979904    0.9790
# 21               36   0.981354  0.978474  0.979912    0.9795
# 22               37   0.985685  0.980671  0.983172    0.9835
# 23               38   0.975359  0.975359  0.975359    0.9760
# 24               39   0.967611  0.977505  0.972533    0.9730
# 25               40   0.980769  0.974849  0.977800    0.9780
# 26               41   0.976555  0.975560  0.976057    0.9765
# 27               42   0.972477  0.976459  0.974464    0.9750
# 28               43   0.977574  0.972617  0.975089    0.9755
# 29               44   0.981057  0.970414  0.975706    0.9755
# 30               45   0.980237  0.986083  0.983152    0.9830
# 31               46   0.970789  0.981299  0.976016    0.9755
# 32               47   0.970559  0.989990  0.980178    0.9800
# 33               48   0.975657  0.978516  0.977084    0.9765
# 34               49   0.974232  0.981038  0.977623    0.9775
# 35               50   0.980943  0.979960  0.980451    0.9805

# %% [markdown]
# Visualizing Random Forest Performance
#
#     Our goal is to beat logistic regression baseline which is
#     ACCURACY: 0.948869
#     PRECISION: 0.947937
#     RECALL: 0.948403
#     F1_SCORE: 0.9475
#
#     According to logistic regression best number of features for this model would be 44.

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score') 
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score') 
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %% [markdown]
#      Now by visualizing the figure above, we can conclude that the best number of features for this model would be 27, , the reason why I chose 27 is because that is the number of features that allowed the model to perform the best across all the evaluation metric

# %% [markdown]
# .

# %% [markdown]
# FINAL RANDOM FOREST MODEL:
#
#     Lets train the final random forest model based on the optimal N number of features

# %%
top_n_features = mi_scores.sort_values(ascending=False).head(27).index.tolist()
x = data[top_n_features]
y = data['Label']

x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, shuffle=True)

rfc= Rfc(n_estimators=500,
         max_depth=32,
         max_features=1.0,
        )

rfc.fit(x_train, y_train)

y_pred = rfc.predict(x_test,)

precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred) 
accuracy = accuracy_score(y_test,y_pred)

print("performance for logistic Model with Top {} features is precision :{}, recall :{}, f1 score :{}, accuracy :{}".format(27,precision,recall,f1,accuracy))
# Out:
# performance for logistic Model with Top 27 features is precision :0.9824902723735408, recall :0.9758454106280193, f1 score :0.9791565681047019, accuracy :0.9785

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       965
#            1       0.98      0.98      0.98      1035
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.98      0.98      2000
# weighted avg       0.98      0.98      0.98      2000
